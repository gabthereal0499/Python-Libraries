# %%
a=10
b=0.5
c=3+3j
d="john"
print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 0.5
# (3+3j)
# john

# %%
a=10
print("/ntype of a:",type (a))
b=0.5
print("/ntype of b:",type(b))
c=2+4j
print("/ntype of c:",type(c))
d="john"
print("/ntype of d:",type(d))
# Out:
# /ntype of a: <class 'int'>
# /ntype of b: <class 'float'>
# /ntype of c: <class 'complex'>
# /ntype of d: <class 'str'>

# %%
x=2
y=1.5
z=4+2j
#convert from int to float:
a=float(x)
#convert from float to int:
b=int(y)
#convert from int to complex:
c=complex(x)
print(a)
print(b)
print(c)
print(type(a))
print(type(b))
print(type(c))
# Out:
# 2.0
# 1
# (2+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
a=int(input())
b=int(input())
print(a+b)
# Out:
# 4
# 7
# 11

# %%
a=int(input("number"))
b=int(input("code"))
print(a+b)
# Out:
# number55
# code2255
# 2310

# %%
a=5
b=5
print(a+b)
# Out:
# 10

# %%
a=int(input("price"))
b=int(input("code"))
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# price5
# code5
# 10
# 0
# 25
# 1.0

# %%
a=str(input("my name is"))
b=int(input("my age is"))
print("my name is",a)
print("my age is",b)
# Out:
# my name isgab
# my age is45
# my name is gab
# my age is 45

# %%
marks=float(input("enter your marks"))
def get_grade(x):
 if x>90:
  print("A")
 elif x>80 and x<90:
  print("B")
 elif x>70 and x<80:
   print('C')
 elif x>60 and x<70:
   print ("D")
get_grade(marks)
# Out:
# enter your marks88.5
# B

# %%
import random
a=(random.randrange(1,10))
print(a)
# Out:
# 6

# %%
import math
x=math.sin(1)
print(x)
# Out:
# 0.8414709848078965

# %%
from math import sin
x=sin(4)
print(x)
# Out:
# -0.7568024953079282

# %%
import random
a=random.randrange(1,50)
y=random.randrange(2,5)
print(a)
print(y)
print(a**y)
# Out:
# 41
# 3
# 68921

# %%
a='john'
b="i'am john"
c='''i'am "john"'''
print(a)
print(b)
print(c)
# Out:
# john
# i'am john
# i'am "john"

# %%
a='john'
b="i'am john"
c='''i'am "john"'''
print(a)
print("\n",b)
print(c)
# Out:
# john
#
#  i'am john
# i'am "john"

# %%
c="hello"
print(c[0:3])
# Out:
# hel

# %%
c="together"
print(c[1:7:2])
# Out:
# oeh

# %%
a="fuck"
print(a[-1:-3:-1])
# Out:
# kc

# %%
list1=["gabru","vishnu","adthil"]
print(list1)
# Out:
# ['gabru', 'vishnu', 'adthil']

# %%
list1=["gabru","vishnu","adthil"]
list1[0]="don"
print(list1)
print(type(list1))
# Out:
# ['don', 'vishnu', 'adthil']
# <class 'list'>

# %%
x="python"
print(x.upper())
# Out:
# PYTHON

# %%
x="GABRIEL"
print(x.lower())
# Out:
# gabriel

# %%
x=" gabriel "
print(x.strip())
# Out:
# gabriel

# %%
h="poda patti otta"
print(h.split(" "))
# Out:
# ['poda', 'patti', 'otta']

# %%
x="love you"
print(x.replace("you","babe"))
# Out:
# love babe

# %%
x="lion"
print(x.isalpha())
# Out:
# False

# %%
sec=int(input("seconds"))
minutes=sec//60
seconds=sec%60
print(minutes)
print(seconds)
# Out:
# seconds200
# 3
# 20

# %%
s="photosynthesis"
list1=list(s)
list1[5]="z"
print(list1)
s=''.join(list1)
print(s)
# Out:
# ['p', 'h', 'o', 't', 'o', 'z', 'y', 'n', 't', 'h', 'e', 's', 'i', 's']
# photozynthesis

# %%
a="john"
a="joshep"
print(a)
# Out:
# joshep

# %%
a="i'm a\"gab\""
print(a)
# Out:
# i'm a"gab"

# %%
a="gab\triel"
print(a)
# Out:
# gab	riel

# %%
a="gab\nriel"
print(a)
# Out:
# gab
# riel

# %%
a='gab\'riel'
print(a)
# Out:
# gab'riel

# %%
a="gab\\riel"
print(a)
# Out:
# gab\riel

# %%
a=input("enter my name")
print(f"my name is {a}")
# Out:
# enter my namegabriel
# my name is gabriel

# %%
a=int(input("age"))
b=(input("place"))
print(f"my age is {a}")
print(f"i'm from {b}")
# Out:
# age50
# placemangakam
# my age is 50
# i'm from mangakam

# %%
s="hhh"
s.count("h")
# Out:
# 3

# %%
gb="hacker"
gb.index("k")
# Out:
# 3

# %%
a="jocker"
print(a*2)
# Out:
# jockerjocker

# %%
a=(input("enter your age"))
print("your age is{}".format(a))
# Out:
# enter your age10
# your age is10

# %%
x=int(input("enter number of car"))
y=int(input("enter number of bike"))
print("i have{} cars and i have{} bikes".format(x,y))
# Out:
# enter number of car5
# enter number of bike6
# i have5 cars and i have6 bikes

# %%
l=[1,2,3,4,]
l.append(6)
print(l)
# Out:
# [1, 2, 3, 4, 6]

# %%
a=[1,2,3,4,5]
a.insert(3,10)
print(a)
# Out:
# [1, 2, 3, 10, 4, 5]

# %%
a=[2,4,6,8,]
a.insert(-2,1)
print(a)
# Out:
# [2, 4, 1, 6, 8]

# %%
a=[1,2,3,4,5]
b=[6,7,8,9,]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
a=[1,2,3,4,5]
a.pop(1)
print(a)
# Out:
# [1, 3, 4, 5]

# %%
a=[1,2,3,4,5]
a.remove(3)
print(a)
# Out:
# [1, 2, 4, 5]

# %%
a2=[123,456,7889,1234]
del a2[2]
print(a2)
# Out:
# [123, 456, 1234]

# %%
a=[1,2,3,4]
a.clear()
print(a)
# Out:
# []

# %%
l1=[20,30,40,50,]
for g in l1:
  print(g+5)
# Out:
# 25
# 35
# 45
# 55

# %%
l1=[]
for f in range(1,8):
  l1.append(f)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a="asdfghjkl"
if"f" in (a):
  print("f is present")
else:
  print("f is absent")
# Out:
# f is present

# %%
a="qwertyui"
if "f" in (a):
  print("f is present")
else:
  print("f is absent")
# Out:
# f is absent

# %%
a=input("what is your name")
print(a)
print(a*10)
print(a[0])
print(a[-3:])
print(a[0:3])
print(a[-1::-1])
c=len(a)
if c<7:
  print(a(6))
else:
    print("string is long enough")
    print(a[1:6])
    print(a.upper())
    print(a.replace("a","e"))
    print(a.replace(""," "))
# Out:
# what is your namegabriel
# gabriel
# gabrielgabrielgabrielgabrielgabrielgabrielgabrielgabrielgabrielgabriel
# g
# iel
# gab
# leirbag
# string is long enough
# abrie
# GABRIEL
# gebriel
#  g a b r i e l

# %%
list1=["gab","vish",1,2,3]
list1.append(4)
print(list1)
list1.remove(1)
print(list1)
# Out:
# ['gab', 'vish', 1, 2, 3, 4]
# ['gab', 'vish', 2, 3, 4]

# %%
s=["follow","tree","sure","kundan"]
s.sort()
print(s)
# Out:
# ['follow', 'kundan', 'sure', 'tree']

# %%
car={
    "brand":"ford",
    "model":"mustang",
    "year":1964
}
x=car.keys()
print(x)#before the change
car["color"]="white"
print(x)#after the change
# Out:
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])

# %%
car={
    "brand":"ford",
    "model":"mustang",
    "year":1964
}
x=car.values()
print(x)#before the change
car["color"]="white"
print(x)#after the change
# Out:
# dict_values(['ford', 'mustang', 1964])
# dict_values(['ford', 'mustang', 1964, 'white'])

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":1964
}
x=thisdict.item()
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-9ba4951933fd> in <cell line: 6>()
#       4     "year":1964
#       5 }
# ----> 6 x=thisdict.item()
#       7 print(x)
#
# AttributeError: 'dict' object has no attribute 'item'

# %%
car={
    "brand":"ford",
    "model":"mustang",
    "year":1964
}
x=car.items()
print(x)#before the change
car["colour"]="red"
print(x)#after the change
# Out:
# dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', 1964)])
# dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', 1964), ('colour', 'red')])

# %%
car={
    "brand":"ford",
    "model":"mustang",
    "year":1964
}
if "model" in car:
  print("model is present")
else:
  print("model is not present")
# Out:
# model is present

# %%
car={
    "brand":"ford",
    "model":"mustang",
    "year":1964
}
if "mustang" in car.values():
  print("model is present")
else:
  print("model is not present")
# Out:
# model is present

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":1964
}
thisdict["year"]=2018
print(thisdict)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 2018}

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":1964
    }
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'ford', 'year': 1964}

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":1964
    }
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'ford', 'model': 'mustang'}

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":1964
    }
thisdict.popitem()
print(len(thisdict))
# Out:
# 2

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":1964
    }
thisdict["colour"]="blue"
print(thisdict)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964, 'colour': 'blue'}

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":1964
    }
del thisdict["brand"]
print(thisdict)
# Out:
# {'model': 'mustang', 'year': 1964}

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":1964
    }
thisdict.clear()
print(thisdict)
# Out:
# {}

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":1964
    }
a=thisdict.copy()
print(a)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":1964
    }
a=dict(thisdict)
print(a)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
myfamily={
    "child1":{
        "name":"emil",
        "year":2024
},
    "child2":{
        "name":"tobias",
        "year":2007
    },
    "child3":{
        "name":"linus",
        "year":2011
    }}
print(myfamily)
# Out:
# {'child1': {'name': 'emil', 'year': 2024}, 'child2': {'name': 'tobias', 'year': 2007}, 'child3': {'name': 'linus', 'year': 2011}}

# %%
myfamily={
    "child1":{"name":"emil",
       "year":2024
},
    "child2":{
        "name":"tobias",
        "year":2007
    },
    "child3":{
        "name":"linus",
        "year":2011
    }}

# %%
child1={
    "name":"emil",
    "year":"2004"
}
child2={
    "name":"tobias",
    "year":2007
}
child3={
    "name":"linus",
    "year":2011
}
myfamily={
    "child1":child1,
    "child2":child2,
    "child3":child3
}
print(myfamily)
# Out:
# {'child1': {'name': 'emil', 'year': '2004'}, 'child2': {'name': 'tobias', 'year': 2007}, 'child3': {'name': 'linus', 'year': 2011}}

# %%
child1={
    "name":"emil",
    "year":"2004"
}
child2={
    "name":"tobias",
    "year":2007
}
child3={
    "name":"linus",
    "year":2011
}
myfamily={
    "child1":child1,
    "child2":child2,
    "child3":child3
}
print(myfamily["child2"]["name"])
# Out:
# tobias

# %%
thisset={"apple","cucuber","tomato"}
print(thisset)
# Out:
# {'tomato', 'cucuber', 'apple'}

# %%
thisset={1,2,3,4,"apple"}
print(thisset)
# Out:
# {1, 2, 3, 4, 'apple'}

# %%
thisset={"apple","jhj","jghgxjkhuihg",True,1,4,2,0}
print(thisset)
# Out:
# {0, True, 2, 4, 'jhj', 'jghgxjkhuihg', 'apple'}

# %%
a=set(("ante","ammate","chimiky",1,2,3,4,))
print(a)
# Out:
# {1, 2, 3, 4, 'chimiky', 'ammate', 'ante'}

# %%
thisset={"apple","orange","strwberry"}
for x in thisset:
  print(x)
# Out:
# orange
# strwberry
# apple

# %%
S={"apple","orange","strwberry"}
if "orange" in S:
 print("orange")
# Out:
# orange

# %%
thisset={"apple","orange","strwberry"}
mylist={"tomato","pottato","ucuber"}
thisset.update(mylist)
print(thisset)
# Out:
# {'ucuber', 'tomato', 'strwberry', 'pottato', 'apple', 'orange'}

# %%
thisset={"apple","orange","strwberry"}
mylist=["tomato","pottato","ucuber"]
thisset.update(mylist)
print(thisset)
# Out:
# {'ucuber', 'tomato', 'strwberry', 'pottato', 'apple', 'orange'}

# %%
thisset={"apple","orange","strwberry"}
mylist=["tomato","pottato","ucuber"]
thisset.remove("orange")
print(thisset)
# Out:
# {'apple', 'strwberry'}

# %%
thisset={"apple","orange","strwberry"}
mylist=["tomato","pottato","ucuber"]
thisset.discard("apple")
print(thisset)
# Out:
# {'orange', 'strwberry'}

# %%
thisset={"apple","orange","strwberry"}
mylist=["tomato","pottato","ucuber"]
thisset.discard("grape")
print(thisset)
# Out:
# {'apple', 'orange', 'strwberry'}

# %%
thisset={"apple","orange","babana"}
thisset.clear()
print(thisset)
# Out:
# set()

# %%
thisset={"apple","orange","babana"}
thisset.del()
print(thisset)
# Out:
#   File "<ipython-input-6-f9a142ffeeac>", line 2
#     thisset.del()
#             ^
# SyntaxError: invalid syntax

# %%
thisset={"apple","banana","orange"}
x=thisset.pop()
print(x)
print(thisset)
# Out:
# apple
# {'orange', 'banana'}

# %%
a={1,2,3,4,5}
b={3,4,5,6,7}
print(a|b)
print(a&b)
# Out:
# {1, 2, 3, 4, 5, 6, 7}
# {3, 4, 5}

# %%
a={1,2,3,4,5}
b={3,4,5,6,7}
print(a-b)
# Out:
# {1, 2}

# %%
a={1,2,3,4,5}
b={3,4,5,6,7}
print(b-a)
# Out:
# {6, 7}

# %%
set1={"a","b","c"}
set2={1,2,3,4}
set3=set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 4, 'b', 'c', 'a'}

# %%
set1={"a","b","c"}
set2={1,2,3,4}
set3=set1|set2
print(set3)
# Out:
# {1, 2, 3, 4, 'a', 'b', 'c'}

# %%
set1={"a","b","c"}
set2={1,2,3,4}
set3={"gab","vish"}
set4={1,2,3,4}
set5=set1|set2|set3|set4
print(set5)
# Out:
# {'vish', 1, 2, 3, 4, 'gab', 'a', 'b', 'c'}

# %%
a={
    "brand":"jockey",
    "color":"red",
    "year":1445
}
a["mark"]="failed"
print(a)
# Out:
# {'brand': 'jockey', 'color': 'red', 'year': 1445, 'mark': 'failed'}

# %%
a={
    "brand":"jockey",
    "color":"red"
}
b={
    "year":1945,
    "model":1654
}
c={
    "name":"gab",
    "age":50
}
abcd={
    "a":a,
    "b":b,
    "c":c
}
print(abcd)
# Out:
# {'a': {'brand': 'jockey', 'color': 'red'}, 'b': {'year': 1945, 'model': 1654}, 'c': {'name': 'gab', 'age': 50}}

# %%
a={
    "brand":"jockey",
    "color":"red",
    "year":1445
    }
for x in a:
    print(x)
# Out:
# brand
# color
# year

# %%
 import random
d={}
n=int(input("entr no"))
x=random.randrange(1,n+1)
d[x]=x*x
print(d)
# Out:
# entr no15
# {3: 9}

# %%
a={
    "name":"gab",
    "year":1234
}
b={
    "name":"vish",
    "year":1345
}
a.update(b)
print(a)
# Out:
# {'name': 'vish', 'year': 1345}

# %%
d={1:8,5:10,15:78,23:10}
sum=0
for i in d.values():
  sum=sum+i
  print(sum)
# Out:
# 8
# 18
# 96
# 106

# %%
d={1:8,5:10,15:78,23:10}
mul=1
for i in d.values():
  mul=mul*i
  print(mul)
# Out:
# 8
# 80
# 6240
# 62400

# %%
a={
    "brand":"jockey",
    "color":"red",
    "year":1445
    }
a.pop("year")
print(a)
# Out:
# {'brand': 'jockey', 'color': 'red'}

# %%
a={
    "brand":"jockey",
    "color":"red",
    "year":1445,
    "year":7667
}
print(a)
# Out:
# {'brand': 'jockey', 'color': 'red', 'year': 7667}

# %%
a={"apple","orsngr","bananas"}
b={"bathroom","cool","apple"}
c=a.difference(b)
print(c)
# Out:
# {'bananas', 'orsngr'}

# %%
a={"apple","orsngr","bananas"}
b={"bathroom","cool","apple"}
c=a-b
print(c)
# Out:
# {'bananas', 'orsngr'}

# %%
a={1,2,3,4,5}
b={4,5,6,7,8}
c=a^b
print(c)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
a={"apple","orsngr","bananas"}
b={"bathroom","cool","apple"}
a.symmetric_difference_update(b)
print(a)
# Out:
# {'cool', 'bathroom', 'orsngr', 'bananas'}

# %%
a=33
b=200
if b>a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
x=int(input("enter a no:"))
y=int(input("enter a no:"))
if x>y:
  print("x is greater than y")
  a=x+y

else:
  print("y is lesser than x")
  a=x-y
print(a)
# Out:
# enter a no:34
# enter a no:45
# y is lesser than x
# -11

# %%
grade=int(input("enter a grade:"))
score=int(input("enter a score:"))
time=int(input("enter a time:"))
if grade>=80 and grade<90:
  print('your grade is a B.')
if score>1000 or time>20:
  print('game over.')
if not (score>1000 or time>20):
  print('game coundinews')
# Out:
# enter a grade:88
# enter a score:1005
# enter a time:25
# your grade is a B.
# game over.

# %% [markdown]
# score=int(input("enter your score:"))
# time=int(input("enter your time:"))
# turns_remaining=int(input("enter your turns:"))
# if (score<1000 or time>20) or turns_remaining==0:
#   print('game over')

# %%
grade=int(input('enter your score:'))
if grade>=90:
  print('A')
elif grade>=80:
  print('B')
elif grade>=70:
  print('c')
elif grade>=60:
  print('d')
else:
  print('f')

# %%
r=1
while r<=3:
  c=1
  while c<=3:
    print(r,",",c,end="  ")
    c+=1
  print()
  r+=1
# Out:
# 1 , 1  1 , 2  1 , 3
# 2 , 1  2 , 2  2 , 3
# 3 , 1  3 , 2  3 , 3

# %%
r=3
i=0
while i<r:
  j=0
  while j<(r-i-1):
   print(" ",end=" ")
   j+=1
  k=0
  while k<i+1:
   print(" * ",end=" ")
   k+=1
  print()
  i+=1
# Out:
#      *
#    *   *
#  *   *   *

# %%
a=$676
print(type(a))
# Out:
#   File "<ipython-input-2-cae63ee1aeca>", line 1
#     a=$676
#       ^
# SyntaxError: invalid syntax
